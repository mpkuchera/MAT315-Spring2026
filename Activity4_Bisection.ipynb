# %% [markdown]
# # Activity: Bisection method and stopping conditions
# In this activity we will implement the bisection method for root-finding and investigate stopping conditions.
#
# <!-- **Objective:** To investigate why we use $|b-a|/2 < \epsilon$ (the interval size) vs. $|f(m)| < \epsilon$ (the function value) as stopping criteria.
#  -->
# To accomplish this, we will look at two functions:
# 1. $f(x) = (x - 1.1)^{11}$
# 2. $g(x) = 10^6(x - 1.1)$

# %%
# imports here
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We can algebraically solve for the roots of both $f(x)$ and $g(x)$, so we don't need a numerical technique here. However, this is a good testing ground to explore the method carefully. Looking at the equations, we can see that both functions have the same root: **$x = 1.1$**.
#
# **1. Let's begin by defining and plotting both functions.**

# %%
def f(x):
#complete me

def g(x):
# complete me

# Let's look at the function near the root
x_vals = np.linspace(1.0, 1.2, 500)

# add plotting code here (you may reference our previous activities)

# %% [markdown]
# **2. Next, we will implement the bisection method.**
#
# Given the same tolerance, we will implement the method with two different stopping conditions:
#     - `bisection_method_func()` will stop when our function value at our midpoint is within the tolerance (e.g. $y = f(x_m)$ is within our tolerance)
#     - `bisection_method_range()` will stop when our interval $(b-a)/2$ is within the tolerance.
#
# **Test for each of your functions with a tolerance of $10^{-7}$ and start with the interval $[a,b] = [1.,2.]$.**
#
# For each test, print out the function name, the stopping condition, the number of iterations, the approximation of the root, and the absolute error.

# %%
def bisection_method_func(func, a, b, tol):
    """
    Define your bisection method for the f(m) stopping condition here
    Note that you can pass a function in as an argument in python! 
    """


def bisection_method_range(func, a, b, tol):
    """
    Define your bisection method for the interval stopping condition here
    Note that you can pass a function in as an argument in python! 
    """

# %%
# Test above functions here and print results legibly (you may want to reference past activities for this too

# %% [markdown]
# **3. Answer the following questions**
#
#
# a) Describe your observations for each stopping condition below, comparing the results for the two functions as a reference.
# b) While it's not the required choice, the most common stopping conditon is the one implemented in

# %% [markdown]
# <font color="green">
#
# Type your responses here
