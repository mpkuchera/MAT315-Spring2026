# %% [markdown]
# # Activity 5: Fixed point method
#
# This correlates to "Crumpet 12" in our book.
#
# We seek to find the roots to the logistic equation:
# $$g(x) = (\alpha - 1)x - \alpha x^2$$ where $\alpha$ is a constant.
#
# **1a. This is a problem where we *can* analytically solve for the roots. Do so in the code below, showing your work** (you can double click this cell to see how I wrote the math here using $\LaTeX{}$).

# %% [markdown]
# <font color="blue" />
#
# Double click and respond here

# %% [markdown]
# To cast this as a fixed point method, we rearrange the root-finding equation to:
# $$x = \alpha x(1-x)$$
# Make sure this step is clear to you.
#
# **1b. Are we guaranteed convergence?** Explain your reasoning below, and consider that we will be trying to apply the fixed point method for various $\alpha$.

# %% [markdown]
# <font color="blue" />
#
# Double click and respond here

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Given a fixed point method of the form $x = f(x)$ we can say the left hand side is the function $y(x) = x$.
#
# We will choose $\alpha = 2.5$ for this part.
#
#
# **2a. Let's also plot the left-hand side and right hand side of the fixed-point method and visually confirm our results from 1a.**
#
# **2b. Compute the fixed point method, and $x_{start} = 0.1$. Plot $x$ as a function of iterations.**

# %%
# complete me

# %% [markdown]
# Modify your code for various starting points, keeping $\alpha$ constant. What do you observe?

# %% [markdown]
# <font color="green" />
#
# Answer here!

# %% [markdown]
# **3. Plot the algorithm "path":**
# 1. $y(x_1) = x_1$
# 2. $f(x_1) = x_2$
# 3. $y(x_2) = x_2$
# 4. $f(x_2) = x_3$
# 5. repeat until convergence, or max iterations reached (no convergence)
#
# So, we want to connect the point $(x_1,x_1)$ to the next point $(x1,f(x_1)=x_2)$, then that point $(x_1,x_2)$ to the point $(x_2,x_2)$, and so on.
#
# **Plot the first 20 iterations of the fixed point method.** Again, with $\alpha = 2.5$ and a starting point of $x_{start} = 0.1$. You can explore the other starting points from **2b.**

# %%
# helpful plotting code:
x1 = 0
x2 = 1
plt.plot([x1, x1], [x1, x2], 'g') #vertical line: steps 1->2
plt.plot([x1, x2], [x2, x2], 'g') #horizontal line: steps 2->3
plt.show()

# %% [markdown]
# Now, for the fun part! Read carefully, because I'm asking you to make a weird plot.
#
# **3. We will explore the convergence for a range of $\alpha = [2.5,40]$**.To do this, we will plot $x_{900-1000}$ vs. $\alpha$.
#
# Meaning, we will run the fixed point method for exactly 1000 iterations for each $alpha$. We will plot the last 100 $x$ values as points (a scatter plot). If the algorithm has converged, the points will all overlay on one another. If not, they will be spread out on the y-axis.
#
# I agree, this is a *weird* plot to make. But this allows us to visualize the affect of alpha on convergence. And you should get a really intersting plot in the end!
#
# Let's look at 2000 values of $\alpha$, and choose a starting point of $x=0.1$
#
# For the `numpy` newbies, you can simpify your code alot by doing all $\alpha$ values at once (see below).
#
# Also, plotting the points really small and in the same color allows us to see the structure of the resulting plot `plt.plot(r_values, x, ',k')`

# %%
alpha_values = np.linspace(2.5, 4.0, 2000) # all alpha values
x_start = np.ones(len(alpha_values))*0.1 # starting x for each alpha
#complete me

# %% [markdown]
# **4. Interpret your results! What is happening as $\alpha$ increases? Why is this occuring?**

# %% [markdown]
# <font color="blue" />
#
# Double click and respond here
