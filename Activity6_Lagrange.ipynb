# %% [markdown]
# ### Activity: Building the Lagrange Interpolating Polynomial
#
# Our goal is to write code that perfectly connects a set of $n+1$ data points. To do this, we need to build an $n$-th degree polynomial $L_n(x)$.
#
# We will begin by plotting a polynomial that passes exactly through the points $(0,1)$, $(1,-3)$, $(2,2)$, $(3,4)$.
#
# ### Part 1: compute polynomials
# **Step 1: The Product Term $p_i(x)$**
# For each data point $(x_i, y_i)$, we first define a product term $p_i(x)$ that multiplies the differences between $x$ and all other $x$-nodes:
# $$p_i(x) = \prod_{j, j \neq i}^n (x - x_j)$$
#
# **Step 2: The Final Polynomial $L_n(x)$**
# We then evaluate this product at our specific node, giving us $p_i(x_i)$. By dividing $p_i(x)$ by $p_i(x_i)$, we create a term that equals 1 at $x_i$ and 0 at all other nodes. We scale this by our $y$-value and sum them all together:
# $$L_n(x) = \sum_{i=0}^{n} \frac{p_i(x)}{p_i(x_i)} y_i$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def p_i(x, x_nodes, i):
    """
    Computes the product term p_i(x)

    arguments: x values of function, x points that function must pass through, i'th p

    returns: array of p_i for all x
    """
    #complete me
    return p

def L_n(x, x_nodes, y_nodes):
    """
    Computes the interpolating polynomial L_n(x).
    
    arguments: x values of function, x points, y points that function must pass through

    returns: array of L_n for all x
    
    """
    # complete me
    
    return L

# %% [markdown]
# ### Part 2: Plotting
#
# Plot the nodes that the function must pass through as visible points: $\{(x_i,y_i)\}$ = $(0,1)$, $(1,-3)$, $(2,2)$, $(3,4)$.
#
# On the same plot, plot your interpolating polynomial.

# %%
# complete me

# %% [markdown]
# ### Part 3. Exploration
#
# a. Use your same functions above to explore your interpolating polynomials passing through a set of points that you define. Play arounf with different options.
# b. For these options, visualize the function behavior outside the region of our data points. **Would you use interpolating polynomials for extrapolation?** Explain below.

# %% [markdown]
# <font color="blue" />
# Complete me
