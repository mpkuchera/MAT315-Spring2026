# %% [markdown]
# # ODE solver exploration
#
# In this activity, we will:
# - Implement Euler and RK2 methods
# - Compare numerical solutions to an exact solution
# - Empirically verify RK2 global error: $\mathcal{O}(h^2)$
#
#
# For this activity, we consider the initial value first-order ODE problem:
#
#
# $$y'(t) = y(t), \quad y(0) = 1$$
#
# With an exact solution of:
# $$ y(t) = e^t $$
#
# We will use this to measure numerical error at $t = 1$.
#
# **1a define our ODE and exact solution**

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t, y):
    # define ODE


def exact(t):
    # define exact solution

# %% [markdown]
# **1b. Define Euler's method and 2nd-order Runge-Kutta**
#
# #### Forward Euler Method
#
# $$
# y_{n+1} = y_n + h f(t_n, y_n)
# $$
#
#
# #### The 2nd-order Runge-Kutta method
#
# $$
# k_1 = f(t_n, y_n)
# $$
#
# $$
# k_2 = f\!\left(t_n + \frac{h}{2}, \; y_n + \frac{h}{2}k_1\right)
# $$
#
# $$
# y_{n+1} = y_n + h k_2
# $$

# %%
def euler(f, t0, y0, h, N):
    # Euler's method (return all y values)


def rk2(f, t0, y0, h, N):
    # 2nd order Runge-Kutta (return all y values)

# %% [markdown]
# **1c.Use your functions above to calcuate the absolute error at $t=1$ for $h=0.5$** and $t = [0,1]$

# %%
# complete me

# %% [markdown]
# **2. for $h = 0.5,0.25,0.125$, plot y(t) in $t = [0,1]$ for both Euler and RK2**
#
# Overlay the ground truth $y(t)$.

# %%
# complete me

# %% [markdown]
# **3.  Now, plot absolute error vs $h$ for $h = \frac{1}{2^{2,3,4,5,6,7}}$ for Euler's method and RK2**
# Plot this on a log-log plot so you can compare the methods in the next part.

# %%
# complete me

# %% [markdown]
# **4. determine order of the error**
#
# Now, as before, find the slope above to find the order of the error. You can do this explicity, or use a fitting function (e.g. `np.polyfit`).
#
# Describe your findings. Do the results agree with analytically derived error calculations?

# %%
# complete me

# %% [markdown]
# Respond here
