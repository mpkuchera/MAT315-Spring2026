# %% [markdown]
# # **Activity 1: Error Exploration**
#
# ---
#
# **Approximating $e^x$**
# In this activity, we will use the **Taylor Series** (an infinite series you will learn more about on Thursday) to approximate the value of $e^x$.
#
# The mathematical definition of the Taylor series for $e^x$ centered at $0$ is:
# $$e^x = \sum_{n=0}^{\infty} \frac{x^n}{n!} = 1 + x + \frac{x^2}{2!} + \frac{x^3}{3!} + \dots$$
#
# **We will invesitgate the accuracy of implementing $e^x$ using this definition on the computer.**
#
# **Goals:**
#
# 1. Investigate types of Error in Section 1.1
# 2. Gain experience with the Jupyter + python + gradescope ecosystem
#
# Before you get started, look at our book's definition of:
# 1. absolute error
# 2. relative error
# 3. truncation error
# 4.
#
# *Note:* We will use `np.float32` for our summation variables to simulate a standard single-precision environment where errors become visible more quickly.

# %%
# imports here
import math
import numpy as np

# %% [markdown]
# **1. In the code cell below, complete the function `taylor_exp(x, n_terms)` that explicitly uses a `for` loop to sum the first $N$ terms of this series.**

# %%
# define function here

# Example: Initialize our sum as a 32-bit float
total = np.float32(0.)
   
# Note: cast values that may have turned into 64-bit back to 32 before doing math with them
# (higher precision wins in operations)
total += np.float32(term)

# %% [markdown]
# **2. For $N = 100$ terms, compute $e^x$ for $x = -20, 15, -10, -5, 0, 5, 10, 15, 20$.**
#
# Compute *absolute error* and *relative error* for each calculation, using `math.exp` for the "ground truth."
#
# I provided some formatted print statements. You can use them to print a nice table.

# %%
# complete me:
# FORMATTING KEY:
# f"..." -> An 'f-string' allows you to put variables or expressions inside { }
# :      -> Separates the value from the formatting instructions
# >      -> Right-aligns the text within the given space
# 4, 18, 12 -> The "width" (number of characters) reserved for that column
print(f"{'N':>4} | {'x':>4} | {'Taylor ':>18} | {'Actual ':>18} | {'Abs Err':>12} | {'Rel Err':>12}")
print("-" * 90)
    
# Format: 
# .8e = Scientific notation with 8 decimal places
# .10f = Fixed decimal with 10 decimal places
print(f"{N:>4} | {x:>4} | {ans:>18.8e} | {actual:>18.8e} | {abs_err:>12.2e}| {rel_err:>12.2e}")

# %% [markdown]
# **In the cell below, write your observations about the behavior of the series for different $x$.**
#
# **Why might this be happening?** Think explicitly about the sum when comparing "good" and "bad" results (and what metric are you using to determine "good" and "bad"?).

# %% [markdown]
# <font color="blue">
#
# Double click here to type

# %% [markdown]
# Let's investigate an example with a high relativer error,  $x = -20$.
#
# **3. Compute $e^x$ for values between $N = 1$ and $N = 5000$ terms.** Compute for as many N as you need to see the trend.
#
# Again, compute *absolute error* and *relative error* for each calculation, using `math.exp` for the "ground truth."

# %%
#complete me:

# %% [markdown]
# **In the cell below, again note your observations and discuss *why* this might be happening.**

# %% [markdown]
# <font color="blue">
#
# Double click and answer here.

# %% [markdown]
# **3. There is a way to use the same Taylor series definition and get a much more accurate answer for $x = -20$ and a subset of other $x$ values.** Use the cell below to try to improve the algorithm for these cases.

# %%
def smarter_exp(x, n_terms):
    #complete me:

# %%
# test function here

# %% [markdown]
# Explain why your algorithm is more accurate given a same $N$ as your first algorithm

# %% [markdown]
# <font color="blue">
#
# Complete me

# %% [markdown]
# ## When complete, submit on gradescope using the link on Moodle
