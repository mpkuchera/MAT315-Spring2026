# %% [markdown]
# # Gaussian Quadrature

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Get stencil and weights
#
# We can use `np.polynomial.legendre.leggauss` to get our stencil and weights.
#
# Let's begin with $n = 2$ stencil points as in class. Are they the same as we derived in class?
#
# Now get the stencil values and weights for $n = 3$. How are these points spaced out? Do you see similarities to the $n = 2 $ case?

# %%
# complete me

# %% [markdown]
# ## 2. Gauss-Legendre Quadrature
#
# a. Complete the function `gaussian_quadrature` below to evaluate $\int_{-1}^1 f(x) dx$
#
# b. Complete the function `f(x,j)` below to compute a simple polynomial of order $j$: $f(x) = x^j$

# %%
def gaussian_quadrature(f, x, w,j):
    

def f(x,j):

# %% [markdown]
# ## 3. Use your functions above to compute the integral
# of polynomials of order 0 through 7 and print the absolute error of the calculation.
# *Hint:* You may want to create a function for the analytic solution.
#
# Describe your results below. Are the results what you expect? Why/why not?

# %%
# code here

# %% [markdown]
# response here

# %% [markdown]
# ## 4. Exploration of stencils.
#
# a. For n = 2,3,4,5 points in the stencil, find what is the highest degree of polynomial each stencil is exact for.
#
# We will define *exact* as an absolute error of less than $1\times 10^{-10}$, which is somewhat close to machine precision while allowing for some accumulation of floating point errors.
#
# b. compare your answers to the trapezoidal rule with the same number of evaluation points (you should already have code for this).

# %%
# complete me
